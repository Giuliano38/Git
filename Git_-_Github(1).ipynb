# %% [markdown]
# Conectar con el drive

# %% [markdown]
# PASOS
#
# > Indented block
#
#
# 1 CONFIGURAR PARAMETROS DE GIT
# 2 MONTAR EL DRIVE DE GOOGLE (NO COLAB)
# 3 CAMBIAR DE DIRECTORIO (%cd)
# 4 LISTAR ARCHIVOS PARA VERIFICAR (!ls)
# 5 CREAR UN GITHUB REPOSITORIO
# 6 CLONAR REPO EN LOCAL (NO COLAB)
# 7 CAMBIAR DE DIRECTORIO ALCLONADO (%cd)
# 8 LISTAR ARCHIVOS PARA VERIFICAR
# 9 PEDIR STATUS DE GIT
# 10 CREAR ARCHIVO DE PYTHON (main.py)
# 11 EJECUTAR PROGRAMA PYTHON
# 12 PEDIR STATUS DE GIT

# %% [markdown]
# Son parametros de configuración para poder ejecutar git (es el local)

# %%
# !git clone https://github.com/Giuliano38/Git.git
# Out:
# Cloning into 'Git'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 588 bytes | 588.00 KiB/s, done.

# %%
# !python main.py
# Out:
# python3: can't open file '/content/drive/MyDrive/GIT1/main.py': [Errno 2] No such file or directory

# %%
# !git config --global user.email "isbh2023.desoft@gmail.com"
# !git config --global user.name "isbh2023desoft"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ES UN COMODIN PARA EJERCICION DE COMANDO EXTERNO
#
# IS SIGNIFICA LIST -LISTA DE CONTENIDO DE LA CARPETA (COMANDO DE LINUX)

# %% [markdown]
# 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

# %%
a = 10
b = 25
c = a + b
print(c)
# Out:
# 35

# %% [markdown]
# % Es un comodin para indicar comando externo o de sistema operativo
#
# cd significa change directory
#
# entonces les estoy diciendo que se cambiede directorio

# %%
# %cd /content/drive/MyDrive/GIT1
# Out:
# /content/drive/MyDrive/GIT1

# %% [markdown]
# Antes del siguiente paso crear el repo en el remoto

# %%
# !git clone https://github.com/Giuliano38/GT1.git
# Out:
# Cloning into 'GT1'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 591 bytes | 19.00 KiB/s, done.

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !ls
# Out:
# Git_-_Github.ipynb  GT1

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git commit -m "1er commit"
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !python /content/git_github/main.py
# Out:
# 3

# %%
# !git add .
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git commit -m "1er commit"
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# TOKEN DEL PERFIL DE GIT
# buscamos el token desde el sitio de git.
# despues de ingresar a git conusuario y contraseña, nos vamos al perfil arriba a la derecha se desplega un menu y a settings
# EN el menu de la izq escroleamos (abajo) hasta DEVELOPER SETTINGS y entramos ahi.
# En el nuevo menu izq vamos a "Personal access tokens"  y debemos generar un token, en la pantalla siguiente debera especificar un nombre al TOKEN y chequee todos los checkbox, ya tenemos generado uno generamos otro.
# copiamos el token y lo pegamos en el INPUT que se muestra al ejecutar esta celda y ENTER.
from getpass import getpass
password = getpass("Enter TOKEN: ")

#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
# Out:
# Enter TOKEN: ··········

# %%
# ELIMINA EL REPO LOCAL si la sentencia anterior informa que ya existe
# !git remote rm origin
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git remote add origin https://github.com/Giuliano38/git_github.git
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push origin main
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
